# %% [markdown]
# # 🧪 Module-04: Challenge Lab

# %% [markdown]
# 🧪 Challenge Lab: Predictions using Naive Bayes Technique
#
# 🎯 Learning Goals
# * Converting text into TF-IDF vectors
# * Splitting data into training and testing sets
# * Training a Naive Bayes classifier
# * Making predictions
# * Computing accuracy
#
# 🧱 Students must complete the missing sections marked as TODO
#
# ✅  When they complete and run the code, they should see:
# *  Model Accuracy

# %%
# Import TF-IDF Vectorizer for converting text to numerical features
from sklearn.feature_extraction.text import TfidfVectorizer

# Import Naive Bayes classifier
from sklearn.naive_bayes import MultinomialNB

# Import function to split data into training/testing sets
from sklearn.model_selection import train_test_split

# Import accuracy metric
from sklearn.metrics import accuracy_score


# ---------------------------
# 1. SAMPLE DATA
# ---------------------------

documents = [
    "Natural language processing is fun",
    "Language models are important in NLP",
    "I enjoy learning about artificial intelligence",
    "Machine learning and NLP are closely related",
    "Deep learning is a subset of machine learning",
    "Transformers have changed NLP forever",
    "Neural networks are used in many AI systems",
    "Text classification is a common NLP task"
]

# 1 = NLP-related, 0 = more general AI-related
labels = [1, 1, 0, 1, 0, 1, 0, 1]


# ---------------------------
# 2. TEXT TO NUMBERS (TF-IDF)
# ---------------------------

# TODO: Create a TfidfVectorizer object
vectorizer = ________________________

# TODO: Fit the vectorizer and transform the documents into TF-IDF features
X = vectorizer.________________________(documents)


# ---------------------------
# 3. SPLIT THE DATA
# ---------------------------

# TODO: Split X and labels into training and test sets
# Hint: use test_size=0.2 and random_state=42
X_train, X_test, y_train, y_test = train_test_split(
    ________________,   # features
    ________________,   # labels
    test_size=0.2,
    random_state=42
)


# ---------------------------
# 4. TRAIN THE CLASSIFIER
# ---------------------------

# TODO: Initialize the Naive Bayes classifier
classifier = ________________________

# TODO: Train the classifier on the training data
classifier.__________________________


# ---------------------------
# 5. MAKE PREDICTIONS
# ---------------------------

# TODO: Predict labels for the test set
y_pred = classifier.________________________


# ---------------------------
# 6. EVALUATE THE MODEL
# ---------------------------

# TODO: Calculate accuracy
accuracy = accuracy_score(_______________, _______________)

print("Model Accuracy:", accuracy)
