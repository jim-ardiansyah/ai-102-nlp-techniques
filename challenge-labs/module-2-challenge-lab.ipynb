# %% [markdown]
# # Module-2 Challenge Lab

# %% [markdown]
# 🧪 Challenge Lab: Advanced Named Entity Recognition with spaCy
#
# 🎯 Learning Goals
# * By the end of this lab, you will be able to:
# * Load and use a spaCy language model
# * Detect named entities in text (people, organizations, places, etc.)
# * Filter entities by type (label)
# * Count how often entities appear
# * Display results in a readable format
#
# 🧱 Students must complete the missing sections marked as TODO
#
# ✅ When they finish the TODOs and run the code, they should be able to:
# * See all entities and their labels
# * See only PERSON/ORG/GPE entities
# * See how many times each appears

# %%
import spacy
from collections import Counter

# 1. LOAD THE ENGLISH MODEL
# TODO: Load the small English model "en_core_web_sm"
nlp = spacy.load("__________")


# 2. SAMPLE TEXT (MULTIPLE SENTENCES)
text = """
Google was founded by Larry Page and Sergey Brin while they were Ph.D. students at Stanford University.
Apple Inc. was created by Steve Jobs, Steve Wozniak, and Ronald Wayne in California.
Microsoft, founded by Bill Gates and Paul Allen, is headquartered in Redmond, Washington.
"""

# 3. PROCESS THE TEXT WITH SPACY
# TODO: Use the nlp model to process the text and create a doc object
doc = nlp(__________)


# 4. PRINT ALL ENTITIES WITH THEIR LABELS
print("=== ALL NAMED ENTITIES ===")
# TODO: Loop through doc.ents and print each entity and its label
# Hint: use ent.text and ent.label_
for ent in doc.ents:
    print(__________, __________)


# 5. FILTER ONLY CERTAIN TYPES OF ENTITIES
# We will keep only people (PERSON), organizations (ORG), and locations (GPE).
allowed_labels = {"PERSON", "ORG", "GPE"}

filtered_entities = []

# TODO: Keep only entities whose label is in allowed_labels
for ent in doc.ents:
    if ent.label_ in allowed_labels:
        filtered_entities.append(__________)

print("\n=== FILTERED ENTITIES (PERSON, ORG, GPE) ===")
print(filtered_entities)


# 6. COUNT HOW MANY TIMES EACH FILTERED ENTITY APPEARS
# TODO: Use Counter to count frequencies of filtered_entities
entity_counts = Counter(______________)

print("\n=== ENTITY FREQUENCY COUNTS ===")
# TODO: Loop over entity_counts.items() and print each entity and its count
for entity, count in entity_counts.items():
    print(__________, "->", __________)
